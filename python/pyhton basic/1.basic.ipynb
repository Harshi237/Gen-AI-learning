# %% [markdown]
# SYNTAX: Syntax is the set of rules that defines how Python code is written and structured.
#
# SEMANTIC: Semantics refers to the meaning and behavior of the symbols, statements, and commands used in a language. It explains what the program actually does when it is executed

# %%
## Basic Syntax Rules In Python
## Case sensitivity- Python is case sensitive

name="Ram"
Name="Ravi"

print(name)
print(Name)
# Out:
# Ram
# Ravi

# %% [markdown]
# INDENTATION: Indentation means leaving spaces (or tabs) at the beginning of a line to define blocks of code. Unlike many languages that use { }, Python uses indentation to show which statements belong together.

# %%
## Indentation
## Python uses indentation to define blocks of code. Consistent use of spaces (commonly 4) or a tab is required.

age=32
if age<30:
    
    print(age)
    
print(age)
# Out:
# 32

# %%
## This is a single line comment
print("Hello World")
# Out:
# Hello World

# %%
## Line Continuation
##Use a backslash (\) to continue a statement to the next line

total=1+2+3+4+5+\
4+5+6

print(total)
# Out:
# 30

# %%
## Multiple Statements on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
##Understand  Semnatics In Python
# variable assignment
age=32 ##age is an integer
name="Krish" ##name is a string

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## Type Inference
variable=10
print(type(variable))
variable="Krish"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=32
if age>30:
    print(age)
# Out:
# 32

# %%
## name error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 ## name error
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
## Code exmaples of indentation
if True:
    print("Correct Indentation")
    if False:
        print("This ont print")
    print("This will print")
print("Outside the if block")
# Out:
# Correct Indentation
# This will print
# Outside the if block
